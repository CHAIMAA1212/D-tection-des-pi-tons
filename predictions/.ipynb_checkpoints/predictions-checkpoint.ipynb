# %%
# !pip install PyYAML
# Out:
# Requirement already satisfied: PyYAML in c:\users\user\downloads\python_yolo\yolo_venv\lib\site-packages (6.0.3)
# WARNING: You are using pip version 21.1.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\users\user\downloads\python_yolo\yolo_venv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading onnxruntime-1.19.2-cp39-cp39-win_amd64.whl (11.1 MB)
# Collecting flatbuffers
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Requirement already satisfied: packaging in c:\users\user\downloads\python_yolo\yolo_venv\lib\site-packages (from onnxruntime) (25.0)
# Collecting protobuf
#   Downloading protobuf-6.33.4-cp39-cp39-win_amd64.whl (436 kB)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\user\downloads\python_yolo\yolo_venv\lib\site-packages (from onnxruntime) (2.0.2)
# Collecting coloredlogs
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Collecting humanfriendly>=9.1
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Collecting pyreadline3
#   Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Collecting mpmath<1.4,>=1.1.0
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: pyreadline3, mpmath, humanfriendly, sympy, protobuf, flatbuffers, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 flatbuffers-25.12.19 humanfriendly-10.0 mpmath-1.3.0 onnxruntime-1.19.2 protobuf-6.33.4 pyreadline3-3.5.4 sympy-1.14.0
# WARNING: You are using pip version 21.1.3; however, version 25.3 is available.
# You should consider upgrading via the 'c:\users\user\downloads\python_yolo\yolo_venv\scripts\python.exe -m pip install --upgrade pip' command.

# %%
import cv2
from yolo_predictions import YOLO_Pred

# %%
yolo = YOLO_Pred('./Model/weights/best.onnx','data.yaml')
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 yolo = YOLO_Pred('./Model/weights/best.onnx','data.yaml')
#
# File c:\Users\user\Downloads\python_yolo\predictions\yolo_predictions.py:20, in YOLO_Pred.__init__(self, onnx_model, data_yaml)
#      17 self.nc = data_yaml['nc']
#      19 # load YOLO model
# ---> 20 self.yolo = cv2.dnn.readNetFromONNX(onnx_model)
#      21 self.yolo.setPreferableBackend(cv2.dnn.DNN_BACKEND_OPENCV)
#      22 self.yolo.setPreferableTarget(cv2.dnn.DNN_TARGET_CPU)
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\onnx\onnx_importer.cpp:1058: error: (-2:Unspecified error) in function 'cv::dnn::dnn4_v20250619::ONNXImporter::handleNode'
# > Node [Conv@ai.onnx]:(onnx_node!node_conv2d) parse error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\layers\layers_common.cpp:106: error: (-5:Bad argument) kernel_size (or kernel_h and kernel_w) not specified in function 'cv::dnn::util::getKernelSize'
# >

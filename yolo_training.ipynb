# %%
import os
os.chdir('/content/drive/MyDrive/yolo_training')

# %%
ls
# Out:
# yolo_training.ipynb  yolov5/

# %%
! git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17778, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (103/103), done.
# remote: Total 17778 (delta 98), reused 51 (delta 51), pack-reused 17624 (from 4)
# Receiving objects: 100% (17778/17778), 17.11 MiB | 13.66 MiB/s, done.
# Resolving deltas: 100% (12082/12082), done.

# %%
ls
# Out:
# yolo_training.ipynb  yolov5/

# %%
os.chdir('yolov5')

# %%
ls
# Out:
# benchmarks.py    data/         hubconf.py      README.md         train.py
# CITATION.cff     data_images/  LICENSE         README.zh-CN.md   tutorial.ipynb
# classify/        detect.py     models/         requirements.txt  utils/
# CONTRIBUTING.md  export.py     pyproject.toml  segment/          val.py

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 36.3 MB/s eta 0:00:00
# ...

# %%
# !python train.py --data data.yaml --cfg yolov5s.yaml --batch-size 8 --name Model --epochs 50
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#       35/49      3.29G    0.02576    0.01903   0.002758         37        640:  11% 18/165 [00:10<01:36,  1.53it/s]/content/drive/MyDrive/yolo_training/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       35/49      3.29G    0.02582    0.01918   0.002776         33        640:  12% 19/165 [00:10<01:14,  1.97it/s]/content/drive/MyDrive/yolo_training/yolov5/train.py:414: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
# !python export.py --weights runs/train/Model2/weights/best.pt --include onnx --simplify --opset 12
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/Model2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=True, mlmodel=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-453-geed9bc19 Python-3.12.12 torch-2.9.0+cu126 CPU
#
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/yolo_training/yolov5/export.py", line 1525, in <module>
#     main(opt)
#   File "/content/drive/MyDrive/yolo_training/yolov5/export.py", line 1520, in main
#     run(**vars(opt))
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 120, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/yolo_training/yolov5/export.py", line 1365, in run
# ...

# %%
# !python export.py --weights runs/train/Model/weights/best.pt --include onnx --opset 11 --simplify
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/Model/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, per_tensor=False, dynamic=False, cache=, simplify=True, mlmodel=False, opset=11, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# YOLOv5 🚀 v7.0-453-geed9bc19 Python-3.12.12 torch-2.9.0+cu126 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from runs/train/Model/weights/best.pt with output shape (1, 25200, 8) (13.7 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0', 'onnxscript'] not found, attempting AutoUpdate...
# Using Python 3.12.12 environment at: /usr
# Resolved 8 packages in 186ms
# Prepared 3 packages in 1.20s
# Installed 3 packages in 245ms
#  + onnx==1.20.1
#  + onnx-ir==0.1.14
#  + onnxscript==0.5.7
#
# ...
